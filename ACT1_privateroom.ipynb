# %% [markdown]
# Private room

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#JALAMOS DATASET
df = pd.read_csv('NEWYORK_SINATIPICOS1.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36322 non-null  float64
#  1   listing_url                                   36322 non-null  object
#  2   scrape_id                                     36322 non-null  float64
#  3   last_scraped                                  36322 non-null  object
#  4   source                                        36322 non-null  object
#  5   name                                          36322 non-null  object
#  6   description                                   36322 non-null  object
#  7   neighborhood_overview                         36322 non-null  object
#  8   picture_url                                   36322 non-null  object
#  9   host_id                                       36322 non-null  float64
#  10  host_url                                      36322 non-null  object
#  11  host_name                                     36322 non-null  object
#  12  host_since                                    36322 non-null  object
#  13  host_location                                 36322 non-null  object
#  14  host_about                                    36322 non-null  object
#  15  host_response_time                            36322 non-null  object
#  16  host_response_rate                            36322 non-null  float64
#  17  host_acceptance_rate                          36322 non-null  float64
#  18  host_is_superhost                             36322 non-null  object
#  19  host_thumbnail_url                            36322 non-null  object
#  20  host_picture_url                              36322 non-null  object
#  21  host_neighbourhood                            36322 non-null  object
#  22  host_listings_count                           36322 non-null  float64
#  23  host_total_listings_count                     36322 non-null  float64
#  24  host_verifications                            36322 non-null  object
#  25  host_has_profile_pic                          36322 non-null  bool
#  26  host_identity_verified                        36322 non-null  bool
#  27  neighbourhood                                 36322 non-null  object
#  28  neighbourhood_cleansed                        36322 non-null  object
#  29  neighbourhood_group_cleansed                  36322 non-null  object
#  30  latitude                                      36322 non-null  float64
#  31  longitude                                     36322 non-null  float64
#  32  property_type                                 36322 non-null  object
#  33  room_type                                     36322 non-null  object
#  34  accommodates                                  36322 non-null  float64
#  35  bathrooms                                     36322 non-null  float64
#  36  bathrooms_text                                36322 non-null  object
#  37  bedrooms                                      36322 non-null  float64
#  38  beds                                          36322 non-null  float64
#  39  amenities                                     36322 non-null  object
#  40  price                                         36322 non-null  float64
#  41  minimum_nights                                36322 non-null  float64
#  42  maximum_nights                                36322 non-null  float64
#  43  minimum_minimum_nights                        36322 non-null  float64
#  44  maximum_minimum_nights                        36322 non-null  float64
#  45  minimum_maximum_nights                        36322 non-null  float64
#  46  maximum_maximum_nights                        36322 non-null  float64
#  47  minimum_nights_avg_ntm                        36322 non-null  float64
#  48  maximum_nights_avg_ntm                        36322 non-null  float64
#  49  calendar_updated                              36322 non-null  object
#  50  has_availability                              36322 non-null  object
#  51  availability_30                               36322 non-null  float64
#  52  availability_60                               36322 non-null  float64
#  53  availability_90                               36322 non-null  float64
#  54  availability_365                              36322 non-null  float64
#  55  calendar_last_scraped                         36322 non-null  object
#  56  number_of_reviews                             36322 non-null  float64
#  57  number_of_reviews_ltm                         36322 non-null  float64
#  58  number_of_reviews_l30d                        36322 non-null  float64
#  59  availability_eoy                              36322 non-null  float64
#  60  number_of_reviews_ly                          36322 non-null  float64
#  61  estimated_occupancy_l365d                     36322 non-null  float64
#  62  estimated_revenue_l365d                       36322 non-null  float64
#  63  first_review                                  36322 non-null  object
#  64  last_review                                   36322 non-null  object
#  65  review_scores_rating                          36322 non-null  float64
#  66  review_scores_accuracy                        36322 non-null  float64
#  67  review_scores_cleanliness                     36322 non-null  float64
#  68  review_scores_checkin                         36322 non-null  float64
#  69  review_scores_communication                   36322 non-null  float64
#  70  review_scores_location                        36322 non-null  float64
#  71  review_scores_value                           36322 non-null  float64
#  72  license                                       36322 non-null  object
#  73  instant_bookable                              36322 non-null  object
#  74  calculated_host_listings_count                36322 non-null  float64
#  75  calculated_host_listings_count_entire_homes   36322 non-null  float64
#  76  calculated_host_listings_count_private_rooms  36322 non-null  float64
#  77  calculated_host_listings_count_shared_rooms   36322 non-null  float64
#  78  reviews_per_month                             36322 non-null  float64
# dtypes: bool(2), float64(45), object(32)
# memory usage: 21.4+ MB
# None

# %%
# 1) Filtrar solo anuncios de tipo "private room"
privateroom_df = df[df["room_type"] == "Private room"].copy()
print(privateroom_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 0 to 36319
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            16346 non-null  float64
#  1   listing_url                                   16346 non-null  object
#  2   scrape_id                                     16346 non-null  float64
#  3   last_scraped                                  16346 non-null  object
#  4   source                                        16346 non-null  object
#  5   name                                          16346 non-null  object
#  6   description                                   16346 non-null  object
#  7   neighborhood_overview                         16346 non-null  object
#  8   picture_url                                   16346 non-null  object
#  9   host_id                                       16346 non-null  float64
#  10  host_url                                      16346 non-null  object
#  11  host_name                                     16346 non-null  object
#  12  host_since                                    16346 non-null  object
#  13  host_location                                 16346 non-null  object
#  14  host_about                                    16346 non-null  object
#  15  host_response_time                            16346 non-null  object
#  16  host_response_rate                            16346 non-null  float64
#  17  host_acceptance_rate                          16346 non-null  float64
#  18  host_is_superhost                             16346 non-null  object
#  19  host_thumbnail_url                            16346 non-null  object
#  20  host_picture_url                              16346 non-null  object
#  21  host_neighbourhood                            16346 non-null  object
#  22  host_listings_count                           16346 non-null  float64
#  23  host_total_listings_count                     16346 non-null  float64
#  24  host_verifications                            16346 non-null  object
#  25  host_has_profile_pic                          16346 non-null  bool
#  26  host_identity_verified                        16346 non-null  bool
#  27  neighbourhood                                 16346 non-null  object
#  28  neighbourhood_cleansed                        16346 non-null  object
#  29  neighbourhood_group_cleansed                  16346 non-null  object
#  30  latitude                                      16346 non-null  float64
#  31  longitude                                     16346 non-null  float64
#  32  property_type                                 16346 non-null  object
#  33  room_type                                     16346 non-null  object
#  34  accommodates                                  16346 non-null  float64
#  35  bathrooms                                     16346 non-null  float64
#  36  bathrooms_text                                16346 non-null  object
#  37  bedrooms                                      16346 non-null  float64
#  38  beds                                          16346 non-null  float64
#  39  amenities                                     16346 non-null  object
#  40  price                                         16346 non-null  float64
#  41  minimum_nights                                16346 non-null  float64
#  42  maximum_nights                                16346 non-null  float64
#  43  minimum_minimum_nights                        16346 non-null  float64
#  44  maximum_minimum_nights                        16346 non-null  float64
#  45  minimum_maximum_nights                        16346 non-null  float64
#  46  maximum_maximum_nights                        16346 non-null  float64
#  47  minimum_nights_avg_ntm                        16346 non-null  float64
#  48  maximum_nights_avg_ntm                        16346 non-null  float64
#  49  calendar_updated                              16346 non-null  object
#  50  has_availability                              16346 non-null  object
#  51  availability_30                               16346 non-null  float64
#  52  availability_60                               16346 non-null  float64
#  53  availability_90                               16346 non-null  float64
#  54  availability_365                              16346 non-null  float64
#  55  calendar_last_scraped                         16346 non-null  object
#  56  number_of_reviews                             16346 non-null  float64
#  57  number_of_reviews_ltm                         16346 non-null  float64
#  58  number_of_reviews_l30d                        16346 non-null  float64
#  59  availability_eoy                              16346 non-null  float64
#  60  number_of_reviews_ly                          16346 non-null  float64
#  61  estimated_occupancy_l365d                     16346 non-null  float64
#  62  estimated_revenue_l365d                       16346 non-null  float64
#  63  first_review                                  16346 non-null  object
#  64  last_review                                   16346 non-null  object
#  65  review_scores_rating                          16346 non-null  float64
#  66  review_scores_accuracy                        16346 non-null  float64
#  67  review_scores_cleanliness                     16346 non-null  float64
#  68  review_scores_checkin                         16346 non-null  float64
#  69  review_scores_communication                   16346 non-null  float64
#  70  review_scores_location                        16346 non-null  float64
#  71  review_scores_value                           16346 non-null  float64
#  72  license                                       16346 non-null  object
#  73  instant_bookable                              16346 non-null  object
#  74  calculated_host_listings_count                16346 non-null  float64
#  75  calculated_host_listings_count_entire_homes   16346 non-null  float64
#  76  calculated_host_listings_count_private_rooms  16346 non-null  float64
#  77  calculated_host_listings_count_shared_rooms   16346 non-null  float64
#  78  reviews_per_month                             16346 non-null  float64
# dtypes: bool(2), float64(45), object(32)
# memory usage: 9.8+ MB
# None

# %%
#  Asegurar que las columnas sean numéricas
privateroom_df["price"] = (
    privateroom_df["price"]
    .astype(str)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

privateroom_df["host_acceptance_rate"] = (
privateroom_df["host_acceptance_rate"]
    .astype(str)
    .str.replace("%", "", regex=False)
    .astype(float)
)

# %%
num = df.select_dtypes(include=["number"])  # Solo columnas numéricas

# Quitar columnas problemáticas:
# - con pocos datos (<2 no nulos)
# - sin variación (nunqiue<=1)
bad = [c for c in num.columns if (num[c].count() < 2) or (num[c].nunique(dropna=True) <= 1)]

# (opcional) quitar identificadores que no tienen sentido en correlación
bad += [c for c in ["id", "scrape_id", "host_id"] if c in num.columns]

# Eliminar columnas
num = num.drop(columns=list(set(bad)))

# %%
# quitar IDs y columnas malas
drop_ids = [c for c in ["id","scrape_id","host_id"] if c in num.columns]
bad = [c for c in num.columns if (num[c].count()<2) or (num[c].nunique(dropna=True)<=1)]
num = num.drop(columns=list(set(drop_ids+bad)))

# --- Correlación bonita ---
corr = num.corr().round(2)


display(corr)  # tabla tipo DataFrame, no texto
# Out:
#                                               host_response_rate  \
# host_response_rate                                          1.00
# host_acceptance_rate                                        0.15
# host_listings_count                                         0.27
# host_total_listings_count                                   0.25
# latitude                                                    0.02
# longitude                                                  -0.02
# accommodates                                                0.02
# price                                                      -0.15
# maximum_nights                                             -0.21
# minimum_maximum_nights                                     -0.21
# maximum_maximum_nights                                     -0.16
# maximum_nights_avg_ntm                                     -0.18
# availability_30                                             0.18
# availability_60                                             0.27
# availability_90                                             0.35
# availability_365                                            0.49
# number_of_reviews                                           0.05
# number_of_reviews_ltm                                       0.24
# availability_eoy                                            0.45
# number_of_reviews_ly                                        0.23
# estimated_occupancy_l365d                                   0.26
# estimated_revenue_l365d                                     0.25
# review_scores_rating                                        0.02
# review_scores_accuracy                                      0.02
# review_scores_cleanliness                                   0.03
# review_scores_checkin                                       0.02
# review_scores_communication                                 0.02
# review_scores_location                                      0.02
# review_scores_value                                         0.01
# calculated_host_listings_count                              0.25
# calculated_host_listings_count_entire_homes                 0.19
# calculated_host_listings_count_private_rooms               -0.02
# reviews_per_month                                           0.18
#
#                                               host_acceptance_rate  \
# host_response_rate                                            0.15
# host_acceptance_rate                                          1.00
# host_listings_count                                           0.03
# host_total_listings_count                                    -0.00
# latitude                                                     -0.03
# longitude                                                    -0.03
# accommodates                                                  0.06
# price                                                         0.07
# maximum_nights                                               -0.04
# minimum_maximum_nights                                        0.05
# maximum_maximum_nights                                        0.08
# maximum_nights_avg_ntm                                        0.07
# availability_30                                               0.06
# availability_60                                               0.07
# availability_90                                               0.07
# availability_365                                              0.08
# number_of_reviews                                             0.06
# number_of_reviews_ltm                                        -0.03
# availability_eoy                                              0.07
# number_of_reviews_ly                                         -0.05
# estimated_occupancy_l365d                                     0.00
# estimated_revenue_l365d                                       0.02
# review_scores_rating                                          0.04
# review_scores_accuracy                                        0.04
# review_scores_cleanliness                                     0.05
# review_scores_checkin                                         0.04
# review_scores_communication                                   0.04
# review_scores_location                                        0.04
# review_scores_value                                           0.04
# calculated_host_listings_count                                0.01
# calculated_host_listings_count_entire_homes                  -0.02
# calculated_host_listings_count_private_rooms                  0.05
# reviews_per_month                                             0.08
#
#                                               host_listings_count  \
# host_response_rate                                           0.27
# host_acceptance_rate                                         0.03
# host_listings_count                                          1.00
# host_total_listings_count                                    0.69
# latitude                                                     0.00
# longitude                                                    0.01
# accommodates                                                 0.01
# price                                                       -0.14
# maximum_nights                                              -0.13
# minimum_maximum_nights                                      -0.11
# maximum_maximum_nights                                      -0.10
# maximum_nights_avg_ntm                                      -0.10
# availability_30                                              0.13
# availability_60                                              0.15
# availability_90                                              0.17
# availability_365                                             0.20
# number_of_reviews                                            0.02
# number_of_reviews_ltm                                        0.10
# availability_eoy                                             0.20
# number_of_reviews_ly                                         0.10
# estimated_occupancy_l365d                                    0.11
# estimated_revenue_l365d                                      0.08
# review_scores_rating                                         0.01
# review_scores_accuracy                                       0.01
# review_scores_cleanliness                                    0.01
# review_scores_checkin                                        0.01
# review_scores_communication                                  0.01
# review_scores_location                                       0.01
# review_scores_value                                          0.00
# calculated_host_listings_count                               0.79
# calculated_host_listings_count_entire_homes                  0.07
# calculated_host_listings_count_private_rooms                 0.09
# reviews_per_month                                            0.06
#
#                                               host_total_listings_count  \
# host_response_rate                                                 0.25
# host_acceptance_rate                                              -0.00
# host_listings_count                                                0.69
# host_total_listings_count                                          1.00
# latitude                                                           0.00
# longitude                                                          0.01
# accommodates                                                      -0.01
# price                                                             -0.13
# maximum_nights                                                    -0.12
# minimum_maximum_nights                                            -0.10
# maximum_maximum_nights                                            -0.09
# maximum_nights_avg_ntm                                            -0.10
# availability_30                                                    0.11
# availability_60                                                    0.14
# availability_90                                                    0.17
# availability_365                                                   0.20
# number_of_reviews                                                  0.01
# number_of_reviews_ltm                                              0.11
# availability_eoy                                                   0.20
# number_of_reviews_ly                                               0.10
# estimated_occupancy_l365d                                          0.11
# estimated_revenue_l365d                                            0.08
# review_scores_rating                                              -0.01
# review_scores_accuracy                                            -0.01
# review_scores_cleanliness                                         -0.00
# review_scores_checkin                                             -0.00
# review_scores_communication                                       -0.01
# review_scores_location                                            -0.00
# review_scores_value                                               -0.01
# calculated_host_listings_count                                     0.60
# calculated_host_listings_count_entire_homes                        0.09
# calculated_host_listings_count_private_rooms                       0.07
# reviews_per_month                                                  0.06
#
#                                               latitude  longitude  \
# host_response_rate                                0.02      -0.02
# host_acceptance_rate                             -0.03      -0.03
# host_listings_count                               0.00       0.01
# host_total_listings_count                         0.00       0.01
# latitude                                          1.00       0.06
# longitude                                         0.06       1.00
# accommodates                                     -0.02      -0.09
# price                                             0.06      -0.32
# maximum_nights                                    0.07      -0.05
# minimum_maximum_nights                            0.03       0.02
# maximum_maximum_nights                            0.04      -0.01
# maximum_nights_avg_ntm                            0.03       0.01
# availability_30                                  -0.07       0.11
# availability_60                                  -0.07       0.10
# availability_90                                  -0.06       0.08
# availability_365                                 -0.03       0.05
# number_of_reviews                                -0.04       0.05
# number_of_reviews_ltm                             0.02       0.01
# availability_eoy                                 -0.05       0.06
# number_of_reviews_ly                              0.01       0.02
# estimated_occupancy_l365d                         0.01       0.02
# estimated_revenue_l365d                           0.00       0.04
# review_scores_rating                             -0.05       0.06
# review_scores_accuracy                           -0.05       0.06
# review_scores_cleanliness                        -0.05       0.06
# review_scores_checkin                            -0.05       0.06
# review_scores_communication                      -0.05       0.06
# review_scores_location                           -0.04       0.03
# review_scores_value                              -0.05       0.06
# calculated_host_listings_count                    0.02       0.00
# calculated_host_listings_count_entire_homes       0.02      -0.03
# calculated_host_listings_count_private_rooms     -0.03       0.13
# reviews_per_month                                -0.04       0.07
#
#                                               accommodates  price  \
# host_response_rate                                    0.02  -0.15
# host_acceptance_rate                                  0.06   0.07
# host_listings_count                                   0.01  -0.14
# host_total_listings_count                            -0.01  -0.13
# latitude                                             -0.02   0.06
# longitude                                            -0.09  -0.32
# accommodates                                          1.00   0.37
# price                                                 0.37   1.00
# maximum_nights                                        0.02   0.16
# minimum_maximum_nights                                0.02   0.13
# maximum_maximum_nights                                0.03   0.13
# maximum_nights_avg_ntm                                0.03   0.13
# availability_30                                      -0.02  -0.15
# availability_60                                      -0.01  -0.18
# availability_90                                      -0.00  -0.20
# availability_365                                      0.04  -0.20
# number_of_reviews                                     0.06  -0.03
# number_of_reviews_ltm                                 0.01  -0.13
# availability_eoy                                      0.03  -0.22
# number_of_reviews_ly                                  0.01  -0.12
# estimated_occupancy_l365d                             0.02  -0.12
# estimated_revenue_l365d                              -0.02  -0.17
# review_scores_rating                                  0.07  -0.04
# review_scores_accuracy                                0.07  -0.04
# review_scores_cleanliness                             0.08  -0.04
# review_scores_checkin                                 0.07  -0.05
# review_scores_communication                           0.07  -0.05
# review_scores_location                                0.07  -0.04
# review_scores_value                                   0.07  -0.05
# calculated_host_listings_count                        0.00  -0.12
# calculated_host_listings_count_entire_homes           0.31   0.24
# calculated_host_listings_count_private_rooms         -0.22  -0.30
# reviews_per_month                                     0.00  -0.14
#
#                                               maximum_nights  \
# host_response_rate                                     -0.21
# host_acceptance_rate                                   -0.04
# host_listings_count                                    -0.13
# host_total_listings_count                              -0.12
# latitude                                                0.07
# longitude                                              -0.05
# accommodates                                            0.02
# price                                                   0.16
# maximum_nights                                          1.00
# minimum_maximum_nights                                  0.73
# maximum_maximum_nights                                  0.76
# maximum_nights_avg_ntm                                  0.75
# availability_30                                        -0.22
# availability_60                                        -0.25
# availability_90                                        -0.27
# availability_365                                       -0.23
# number_of_reviews                                      -0.06
# number_of_reviews_ltm                                  -0.07
# availability_eoy                                       -0.27
# number_of_reviews_ly                                   -0.07
# estimated_occupancy_l365d                              -0.09
# estimated_revenue_l365d                                -0.11
# review_scores_rating                                   -0.05
# review_scores_accuracy                                 -0.04
# review_scores_cleanliness                              -0.05
# review_scores_checkin                                  -0.04
# review_scores_communication                            -0.04
# review_scores_location                                 -0.04
# review_scores_value                                    -0.04
# calculated_host_listings_count                         -0.13
# calculated_host_listings_count_entire_homes            -0.00
# calculated_host_listings_count_private_rooms           -0.08
# reviews_per_month                                      -0.13
#
#                                               minimum_maximum_nights  ...  \
# host_response_rate                                             -0.21  ...
# host_acceptance_rate                                            0.05  ...
# host_listings_count                                            -0.11  ...
# host_total_listings_count                                      -0.10  ...
# latitude                                                        0.03  ...
# longitude                                                       0.02  ...
# accommodates                                                    0.02  ...
# price                                                           0.13  ...
# maximum_nights                                                  0.73  ...
# minimum_maximum_nights                                          1.00  ...
# maximum_maximum_nights                                          0.94  ...
# maximum_nights_avg_ntm                                          0.98  ...
# availability_30                                                -0.21  ...
# availability_60                                                -0.25  ...
# availability_90                                                -0.27  ...
# availability_365                                               -0.20  ...
# number_of_reviews                                               0.01  ...
# number_of_reviews_ltm                                          -0.06  ...
# availability_eoy                                               -0.25  ...
# number_of_reviews_ly                                           -0.06  ...
# estimated_occupancy_l365d                                      -0.08  ...
# estimated_revenue_l365d                                        -0.08  ...
# review_scores_rating                                            0.05  ...
# review_scores_accuracy                                          0.05  ...
# review_scores_cleanliness                                       0.05  ...
# review_scores_checkin                                           0.05  ...
# review_scores_communication                                     0.06  ...
# review_scores_location                                          0.05  ...
# review_scores_value                                             0.06  ...
# calculated_host_listings_count                                 -0.11  ...
# calculated_host_listings_count_entire_homes                     0.03  ...
# calculated_host_listings_count_private_rooms                   -0.04  ...
# reviews_per_month                                              -0.07  ...
#
#                                               review_scores_accuracy  \
# host_response_rate                                              0.02
# host_acceptance_rate                                            0.04
# host_listings_count                                             0.01
# host_total_listings_count                                      -0.01
# latitude                                                       -0.05
# longitude                                                       0.06
# accommodates                                                    0.07
# price                                                          -0.04
# maximum_nights                                                 -0.04
# minimum_maximum_nights                                          0.05
# maximum_maximum_nights                                          0.03
# maximum_nights_avg_ntm                                          0.04
# availability_30                                                -0.10
# availability_60                                                -0.10
# availability_90                                                -0.09
# availability_365                                               -0.08
# number_of_reviews                                               0.41
# number_of_reviews_ltm                                           0.24
# availability_eoy                                               -0.08
# number_of_reviews_ly                                            0.23
# estimated_occupancy_l365d                                       0.25
# estimated_revenue_l365d                                         0.24
# review_scores_rating                                            0.99
# review_scores_accuracy                                          1.00
# review_scores_cleanliness                                       0.99
# review_scores_checkin                                           0.99
# review_scores_communication                                     0.99
# review_scores_location                                          0.99
# review_scores_value                                             0.99
# calculated_host_listings_count                                  0.01
# calculated_host_listings_count_entire_homes                     0.05
# calculated_host_listings_count_private_rooms                    0.08
# reviews_per_month                                              -0.00
#
#                                               review_scores_cleanliness  \
# host_response_rate                                                 0.03
# host_acceptance_rate                                               0.05
# host_listings_count                                                0.01
# host_total_listings_count                                         -0.00
# latitude                                                          -0.05
# longitude                                                          0.06
# accommodates                                                       0.08
# price                                                             -0.04
# maximum_nights                                                    -0.05
# minimum_maximum_nights                                             0.05
# maximum_maximum_nights                                             0.02
# maximum_nights_avg_ntm                                             0.04
# availability_30                                                   -0.09
# availability_60                                                   -0.08
# availability_90                                                   -0.08
# availability_365                                                  -0.07
# number_of_reviews                                                  0.41
# number_of_reviews_ltm                                              0.24
# availability_eoy                                                  -0.07
# number_of_reviews_ly                                               0.24
# estimated_occupancy_l365d                                          0.26
# estimated_revenue_l365d                                            0.25
# review_scores_rating                                               0.99
# review_scores_accuracy                                             0.99
# review_scores_cleanliness                                          1.00
# review_scores_checkin                                              0.99
# review_scores_communication                                        0.99
# review_scores_location                                             0.98
# review_scores_value                                                0.99
# calculated_host_listings_count                                     0.02
# calculated_host_listings_count_entire_homes                        0.05
# calculated_host_listings_count_private_rooms                       0.09
# reviews_per_month                                                  0.01
#
#                                               review_scores_checkin  \
# host_response_rate                                             0.02
# host_acceptance_rate                                           0.04
# host_listings_count                                            0.01
# host_total_listings_count                                     -0.00
# latitude                                                      -0.05
# longitude                                                      0.06
# accommodates                                                   0.07
# price                                                         -0.05
# maximum_nights                                                -0.04
# minimum_maximum_nights                                         0.05
# maximum_maximum_nights                                         0.03
# maximum_nights_avg_ntm                                         0.04
# availability_30                                               -0.10
# availability_60                                               -0.09
# availability_90                                               -0.09
# availability_365                                              -0.08
# number_of_reviews                                              0.40
# number_of_reviews_ltm                                          0.24
# availability_eoy                                              -0.08
# number_of_reviews_ly                                           0.24
# estimated_occupancy_l365d                                      0.25
# estimated_revenue_l365d                                        0.24
# review_scores_rating                                           0.99
# review_scores_accuracy                                         0.99
# review_scores_cleanliness                                      0.99
# review_scores_checkin                                          1.00
# review_scores_communication                                    0.99
# review_scores_location                                         0.99
# review_scores_value                                            0.99
# calculated_host_listings_count                                 0.02
# calculated_host_listings_count_entire_homes                    0.05
# calculated_host_listings_count_private_rooms                   0.09
# reviews_per_month                                             -0.01
#
#                                               review_scores_communication  \
# host_response_rate                                                   0.02
# host_acceptance_rate                                                 0.04
# host_listings_count                                                  0.01
# host_total_listings_count                                           -0.01
# latitude                                                            -0.05
# longitude                                                            0.06
# accommodates                                                         0.07
# price                                                               -0.05
# maximum_nights                                                      -0.04
# minimum_maximum_nights                                               0.06
# maximum_maximum_nights                                               0.03
# maximum_nights_avg_ntm                                               0.04
# availability_30                                                     -0.10
# availability_60                                                     -0.09
# availability_90                                                     -0.09
# availability_365                                                    -0.08
# number_of_reviews                                                    0.41
# number_of_reviews_ltm                                                0.24
# availability_eoy                                                    -0.08
# number_of_reviews_ly                                                 0.23
# estimated_occupancy_l365d                                            0.25
# estimated_revenue_l365d                                              0.24
# review_scores_rating                                                 0.99
# review_scores_accuracy                                               0.99
# review_scores_cleanliness                                            0.99
# review_scores_checkin                                                0.99
# review_scores_communication                                          1.00
# review_scores_location                                               0.99
# review_scores_value                                                  0.99
# calculated_host_listings_count                                       0.01
# calculated_host_listings_count_entire_homes                          0.05
# calculated_host_listings_count_private_rooms                         0.09
# reviews_per_month                                                   -0.01
#
#                                               review_scores_location  \
# host_response_rate                                              0.02
# host_acceptance_rate                                            0.04
# host_listings_count                                             0.01
# host_total_listings_count                                      -0.00
# latitude                                                       -0.04
# longitude                                                       0.03
# accommodates                                                    0.07
# price                                                          -0.04
# maximum_nights                                                 -0.04
# minimum_maximum_nights                                          0.05
# maximum_maximum_nights                                          0.03
# maximum_nights_avg_ntm                                          0.04
# availability_30                                                -0.10
# availability_60                                                -0.09
# availability_90                                                -0.09
# availability_365                                               -0.08
# number_of_reviews                                               0.40
# number_of_reviews_ltm                                           0.24
# availability_eoy                                               -0.08
# number_of_reviews_ly                                            0.24
# estimated_occupancy_l365d                                       0.25
# estimated_revenue_l365d                                         0.24
# review_scores_rating                                            0.99
# review_scores_accuracy                                          0.99
# review_scores_cleanliness                                       0.98
# review_scores_checkin                                           0.99
# review_scores_communication                                     0.99
# review_scores_location                                          1.00
# review_scores_value                                             0.99
# calculated_host_listings_count                                  0.01
# calculated_host_listings_count_entire_homes                     0.05
# calculated_host_listings_count_private_rooms                    0.08
# reviews_per_month                                              -0.01
#
#                                               review_scores_value  \
# host_response_rate                                           0.01
# host_acceptance_rate                                         0.04
# host_listings_count                                          0.00
# host_total_listings_count                                   -0.01
# latitude                                                    -0.05
# longitude                                                    0.06
# accommodates                                                 0.07
# price                                                       -0.05
# maximum_nights                                              -0.04
# minimum_maximum_nights                                       0.06
# maximum_maximum_nights                                       0.03
# maximum_nights_avg_ntm                                       0.04
# availability_30                                             -0.10
# availability_60                                             -0.10
# availability_90                                             -0.10
# availability_365                                            -0.09
# number_of_reviews                                            0.41
# number_of_reviews_ltm                                        0.23
# availability_eoy                                            -0.09
# number_of_reviews_ly                                         0.23
# estimated_occupancy_l365d                                    0.24
# estimated_revenue_l365d                                      0.24
# review_scores_rating                                         0.99
# review_scores_accuracy                                       0.99
# review_scores_cleanliness                                    0.99
# review_scores_checkin                                        0.99
# review_scores_communication                                  0.99
# review_scores_location                                       0.99
# review_scores_value                                          1.00
# calculated_host_listings_count                               0.00
# calculated_host_listings_count_entire_homes                  0.04
# calculated_host_listings_count_private_rooms                 0.09
# reviews_per_month                                           -0.00
#
#                                               calculated_host_listings_count  \
# host_response_rate                                                      0.25
# host_acceptance_rate                                                    0.01
# host_listings_count                                                     0.79
# host_total_listings_count                                               0.60
# latitude                                                                0.02
# longitude                                                               0.00
# accommodates                                                            0.00
# price                                                                  -0.12
# maximum_nights                                                         -0.13
# minimum_maximum_nights                                                 -0.11
# maximum_maximum_nights                                                 -0.09
# maximum_nights_avg_ntm                                                 -0.10
# availability_30                                                         0.12
# availability_60                                                         0.15
# availability_90                                                         0.16
# availability_365                                                        0.19
# number_of_reviews                                                       0.02
# number_of_reviews_ltm                                                   0.09
# availability_eoy                                                        0.19
# number_of_reviews_ly                                                    0.09
# estimated_occupancy_l365d                                               0.09
# estimated_revenue_l365d                                                 0.07
# review_scores_rating                                                    0.01
# review_scores_accuracy                                                  0.01
# review_scores_cleanliness                                               0.02
# review_scores_checkin                                                   0.02
# review_scores_communication                                             0.01
# review_scores_location                                                  0.01
# review_scores_value                                                     0.00
# calculated_host_listings_count                                          1.00
# calculated_host_listings_count_entire_homes                             0.06
# calculated_host_listings_count_private_rooms                            0.11
# reviews_per_month                                                       0.05
#
#                                               calculated_host_listings_count_entire_homes  \
# host_response_rate                                                                   0.19
# host_acceptance_rate                                                                -0.02
# host_listings_count                                                                  0.07
# host_total_listings_count                                                            0.09
# latitude                                                                             0.02
# longitude                                                                           -0.03
# accommodates                                                                         0.31
# price                                                                                0.24
# maximum_nights                                                                      -0.00
# minimum_maximum_nights                                                               0.03
# maximum_maximum_nights                                                              -0.00
# maximum_nights_avg_ntm                                                               0.01
# availability_30                                                                     -0.04
# availability_60                                                                     -0.02
# availability_90                                                                     -0.00
# availability_365                                                                     0.07
# number_of_reviews                                                                    0.04
# number_of_reviews_ltm                                                                0.09
# availability_eoy                                                                     0.04
# number_of_reviews_ly                                                                 0.08
# estimated_occupancy_l365d                                                            0.08
# estimated_revenue_l365d                                                              0.04
# review_scores_rating                                                                 0.05
# review_scores_accuracy                                                               0.05
# review_scores_cleanliness                                                            0.05
# review_scores_checkin                                                                0.05
# review_scores_communication                                                          0.05
# review_scores_location                                                               0.05
# review_scores_value                                                                  0.04
# calculated_host_listings_count                                                       0.06
# calculated_host_listings_count_entire_homes                                          1.00
# calculated_host_listings_count_private_rooms                                        -0.33
# reviews_per_month                                                                    0.02
#
#                                               calculated_host_listings_count_private_rooms  \
# host_response_rate                                                                   -0.02
# host_acceptance_rate                                                                  0.05
# host_listings_count                                                                   0.09
# host_total_listings_count                                                             0.07
# latitude                                                                             -0.03
# longitude                                                                             0.13
# accommodates                                                                         -0.22
# price                                                                                -0.30
# maximum_nights                                                                       -0.08
# minimum_maximum_nights                                                               -0.04
# maximum_maximum_nights                                                               -0.05
# maximum_nights_avg_ntm                                                               -0.04
# availability_30                                                                       0.09
# availability_60                                                                       0.08
# availability_90                                                                       0.07
# availability_365                                                                     -0.00
# number_of_reviews                                                                     0.08
# number_of_reviews_ltm                                                                 0.00
# availability_eoy                                                                      0.03
# number_of_reviews_ly                                                                 -0.00
# estimated_occupancy_l365d                                                             0.01
# estimated_revenue_l365d                                                               0.05
# review_scores_rating                                                                  0.09
# review_scores_accuracy                                                                0.08
# review_scores_cleanliness                                                             0.09
# review_scores_checkin                                                                 0.09
# review_scores_communication                                                           0.09
# review_scores_location                                                                0.08
# review_scores_value                                                                   0.09
# calculated_host_listings_count                                                        0.11
# calculated_host_listings_count_entire_homes                                          -0.33
# calculated_host_listings_count_private_rooms                                          1.00
# reviews_per_month                                                                     0.07
#
#                                               reviews_per_month
# host_response_rate                                         0.18
# host_acceptance_rate                                       0.08
# host_listings_count                                        0.06
# host_total_listings_count                                  0.06
# latitude                                                  -0.04
# longitude                                                  0.07
# accommodates                                               0.00
# price                                                     -0.14
# maximum_nights                                            -0.13
# minimum_maximum_nights                                    -0.07
# maximum_maximum_nights                                    -0.07
# maximum_nights_avg_ntm                                    -0.07
# availability_30                                            0.12
# availability_60                                            0.14
# availability_90                                            0.16
# availability_365                                           0.16
# number_of_reviews                                          0.32
# number_of_reviews_ltm                                      0.12
# availability_eoy                                           0.17
# number_of_reviews_ly                                       0.05
# estimated_occupancy_l365d                                  0.16
# estimated_revenue_l365d                                    0.16
# review_scores_rating                                      -0.00
# review_scores_accuracy                                    -0.00
# review_scores_cleanliness                                  0.01
# review_scores_checkin                                     -0.01
# review_scores_communication                               -0.01
# review_scores_location                                    -0.01
# review_scores_value                                       -0.00
# calculated_host_listings_count                             0.05
# calculated_host_listings_count_entire_homes                0.02
# calculated_host_listings_count_private_rooms               0.07
# reviews_per_month                                          1.00
#
# [33 rows x 33 columns]

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables 
Corr_Factors1= abs(corr)
Corr_Factors1
# Out:
#                                               host_response_rate  \
# host_response_rate                                          1.00
# host_acceptance_rate                                        0.15
# host_listings_count                                         0.27
# host_total_listings_count                                   0.25
# latitude                                                    0.02
# longitude                                                   0.02
# accommodates                                                0.02
# price                                                       0.15
# maximum_nights                                              0.21
# minimum_maximum_nights                                      0.21
# maximum_maximum_nights                                      0.16
# maximum_nights_avg_ntm                                      0.18
# availability_30                                             0.18
# availability_60                                             0.27
# availability_90                                             0.35
# availability_365                                            0.49
# number_of_reviews                                           0.05
# number_of_reviews_ltm                                       0.24
# availability_eoy                                            0.45
# number_of_reviews_ly                                        0.23
# estimated_occupancy_l365d                                   0.26
# estimated_revenue_l365d                                     0.25
# review_scores_rating                                        0.02
# review_scores_accuracy                                      0.02
# review_scores_cleanliness                                   0.03
# review_scores_checkin                                       0.02
# review_scores_communication                                 0.02
# review_scores_location                                      0.02
# review_scores_value                                         0.01
# calculated_host_listings_count                              0.25
# calculated_host_listings_count_entire_homes                 0.19
# calculated_host_listings_count_private_rooms                0.02
# reviews_per_month                                           0.18
#
#                                               host_acceptance_rate  \
# host_response_rate                                            0.15
# host_acceptance_rate                                          1.00
# host_listings_count                                           0.03
# host_total_listings_count                                     0.00
# latitude                                                      0.03
# longitude                                                     0.03
# accommodates                                                  0.06
# price                                                         0.07
# maximum_nights                                                0.04
# minimum_maximum_nights                                        0.05
# maximum_maximum_nights                                        0.08
# maximum_nights_avg_ntm                                        0.07
# availability_30                                               0.06
# availability_60                                               0.07
# availability_90                                               0.07
# availability_365                                              0.08
# number_of_reviews                                             0.06
# number_of_reviews_ltm                                         0.03
# availability_eoy                                              0.07
# number_of_reviews_ly                                          0.05
# estimated_occupancy_l365d                                     0.00
# estimated_revenue_l365d                                       0.02
# review_scores_rating                                          0.04
# review_scores_accuracy                                        0.04
# review_scores_cleanliness                                     0.05
# review_scores_checkin                                         0.04
# review_scores_communication                                   0.04
# review_scores_location                                        0.04
# review_scores_value                                           0.04
# calculated_host_listings_count                                0.01
# calculated_host_listings_count_entire_homes                   0.02
# calculated_host_listings_count_private_rooms                  0.05
# reviews_per_month                                             0.08
#
#                                               host_listings_count  \
# host_response_rate                                           0.27
# host_acceptance_rate                                         0.03
# host_listings_count                                          1.00
# host_total_listings_count                                    0.69
# latitude                                                     0.00
# longitude                                                    0.01
# accommodates                                                 0.01
# price                                                        0.14
# maximum_nights                                               0.13
# minimum_maximum_nights                                       0.11
# maximum_maximum_nights                                       0.10
# maximum_nights_avg_ntm                                       0.10
# availability_30                                              0.13
# availability_60                                              0.15
# availability_90                                              0.17
# availability_365                                             0.20
# number_of_reviews                                            0.02
# number_of_reviews_ltm                                        0.10
# availability_eoy                                             0.20
# number_of_reviews_ly                                         0.10
# estimated_occupancy_l365d                                    0.11
# estimated_revenue_l365d                                      0.08
# review_scores_rating                                         0.01
# review_scores_accuracy                                       0.01
# review_scores_cleanliness                                    0.01
# review_scores_checkin                                        0.01
# review_scores_communication                                  0.01
# review_scores_location                                       0.01
# review_scores_value                                          0.00
# calculated_host_listings_count                               0.79
# calculated_host_listings_count_entire_homes                  0.07
# calculated_host_listings_count_private_rooms                 0.09
# reviews_per_month                                            0.06
#
#                                               host_total_listings_count  \
# host_response_rate                                                 0.25
# host_acceptance_rate                                               0.00
# host_listings_count                                                0.69
# host_total_listings_count                                          1.00
# latitude                                                           0.00
# longitude                                                          0.01
# accommodates                                                       0.01
# price                                                              0.13
# maximum_nights                                                     0.12
# minimum_maximum_nights                                             0.10
# maximum_maximum_nights                                             0.09
# maximum_nights_avg_ntm                                             0.10
# availability_30                                                    0.11
# availability_60                                                    0.14
# availability_90                                                    0.17
# availability_365                                                   0.20
# number_of_reviews                                                  0.01
# number_of_reviews_ltm                                              0.11
# availability_eoy                                                   0.20
# number_of_reviews_ly                                               0.10
# estimated_occupancy_l365d                                          0.11
# estimated_revenue_l365d                                            0.08
# review_scores_rating                                               0.01
# review_scores_accuracy                                             0.01
# review_scores_cleanliness                                          0.00
# review_scores_checkin                                              0.00
# review_scores_communication                                        0.01
# review_scores_location                                             0.00
# review_scores_value                                                0.01
# calculated_host_listings_count                                     0.60
# calculated_host_listings_count_entire_homes                        0.09
# calculated_host_listings_count_private_rooms                       0.07
# reviews_per_month                                                  0.06
#
#                                               latitude  longitude  \
# host_response_rate                                0.02       0.02
# host_acceptance_rate                              0.03       0.03
# host_listings_count                               0.00       0.01
# host_total_listings_count                         0.00       0.01
# latitude                                          1.00       0.06
# longitude                                         0.06       1.00
# accommodates                                      0.02       0.09
# price                                             0.06       0.32
# maximum_nights                                    0.07       0.05
# minimum_maximum_nights                            0.03       0.02
# maximum_maximum_nights                            0.04       0.01
# maximum_nights_avg_ntm                            0.03       0.01
# availability_30                                   0.07       0.11
# availability_60                                   0.07       0.10
# availability_90                                   0.06       0.08
# availability_365                                  0.03       0.05
# number_of_reviews                                 0.04       0.05
# number_of_reviews_ltm                             0.02       0.01
# availability_eoy                                  0.05       0.06
# number_of_reviews_ly                              0.01       0.02
# estimated_occupancy_l365d                         0.01       0.02
# estimated_revenue_l365d                           0.00       0.04
# review_scores_rating                              0.05       0.06
# review_scores_accuracy                            0.05       0.06
# review_scores_cleanliness                         0.05       0.06
# review_scores_checkin                             0.05       0.06
# review_scores_communication                       0.05       0.06
# review_scores_location                            0.04       0.03
# review_scores_value                               0.05       0.06
# calculated_host_listings_count                    0.02       0.00
# calculated_host_listings_count_entire_homes       0.02       0.03
# calculated_host_listings_count_private_rooms      0.03       0.13
# reviews_per_month                                 0.04       0.07
#
#                                               accommodates  price  \
# host_response_rate                                    0.02   0.15
# host_acceptance_rate                                  0.06   0.07
# host_listings_count                                   0.01   0.14
# host_total_listings_count                             0.01   0.13
# latitude                                              0.02   0.06
# longitude                                             0.09   0.32
# accommodates                                          1.00   0.37
# price                                                 0.37   1.00
# maximum_nights                                        0.02   0.16
# minimum_maximum_nights                                0.02   0.13
# maximum_maximum_nights                                0.03   0.13
# maximum_nights_avg_ntm                                0.03   0.13
# availability_30                                       0.02   0.15
# availability_60                                       0.01   0.18
# availability_90                                       0.00   0.20
# availability_365                                      0.04   0.20
# number_of_reviews                                     0.06   0.03
# number_of_reviews_ltm                                 0.01   0.13
# availability_eoy                                      0.03   0.22
# number_of_reviews_ly                                  0.01   0.12
# estimated_occupancy_l365d                             0.02   0.12
# estimated_revenue_l365d                               0.02   0.17
# review_scores_rating                                  0.07   0.04
# review_scores_accuracy                                0.07   0.04
# review_scores_cleanliness                             0.08   0.04
# review_scores_checkin                                 0.07   0.05
# review_scores_communication                           0.07   0.05
# review_scores_location                                0.07   0.04
# review_scores_value                                   0.07   0.05
# calculated_host_listings_count                        0.00   0.12
# calculated_host_listings_count_entire_homes           0.31   0.24
# calculated_host_listings_count_private_rooms          0.22   0.30
# reviews_per_month                                     0.00   0.14
#
#                                               maximum_nights  \
# host_response_rate                                      0.21
# host_acceptance_rate                                    0.04
# host_listings_count                                     0.13
# host_total_listings_count                               0.12
# latitude                                                0.07
# longitude                                               0.05
# accommodates                                            0.02
# price                                                   0.16
# maximum_nights                                          1.00
# minimum_maximum_nights                                  0.73
# maximum_maximum_nights                                  0.76
# maximum_nights_avg_ntm                                  0.75
# availability_30                                         0.22
# availability_60                                         0.25
# availability_90                                         0.27
# availability_365                                        0.23
# number_of_reviews                                       0.06
# number_of_reviews_ltm                                   0.07
# availability_eoy                                        0.27
# number_of_reviews_ly                                    0.07
# estimated_occupancy_l365d                               0.09
# estimated_revenue_l365d                                 0.11
# review_scores_rating                                    0.05
# review_scores_accuracy                                  0.04
# review_scores_cleanliness                               0.05
# review_scores_checkin                                   0.04
# review_scores_communication                             0.04
# review_scores_location                                  0.04
# review_scores_value                                     0.04
# calculated_host_listings_count                          0.13
# calculated_host_listings_count_entire_homes             0.00
# calculated_host_listings_count_private_rooms            0.08
# reviews_per_month                                       0.13
#
#                                               minimum_maximum_nights  ...  \
# host_response_rate                                              0.21  ...
# host_acceptance_rate                                            0.05  ...
# host_listings_count                                             0.11  ...
# host_total_listings_count                                       0.10  ...
# latitude                                                        0.03  ...
# longitude                                                       0.02  ...
# accommodates                                                    0.02  ...
# price                                                           0.13  ...
# maximum_nights                                                  0.73  ...
# minimum_maximum_nights                                          1.00  ...
# maximum_maximum_nights                                          0.94  ...
# maximum_nights_avg_ntm                                          0.98  ...
# availability_30                                                 0.21  ...
# availability_60                                                 0.25  ...
# availability_90                                                 0.27  ...
# availability_365                                                0.20  ...
# number_of_reviews                                               0.01  ...
# number_of_reviews_ltm                                           0.06  ...
# availability_eoy                                                0.25  ...
# number_of_reviews_ly                                            0.06  ...
# estimated_occupancy_l365d                                       0.08  ...
# estimated_revenue_l365d                                         0.08  ...
# review_scores_rating                                            0.05  ...
# review_scores_accuracy                                          0.05  ...
# review_scores_cleanliness                                       0.05  ...
# review_scores_checkin                                           0.05  ...
# review_scores_communication                                     0.06  ...
# review_scores_location                                          0.05  ...
# review_scores_value                                             0.06  ...
# calculated_host_listings_count                                  0.11  ...
# calculated_host_listings_count_entire_homes                     0.03  ...
# calculated_host_listings_count_private_rooms                    0.04  ...
# reviews_per_month                                               0.07  ...
#
#                                               review_scores_accuracy  \
# host_response_rate                                              0.02
# host_acceptance_rate                                            0.04
# host_listings_count                                             0.01
# host_total_listings_count                                       0.01
# latitude                                                        0.05
# longitude                                                       0.06
# accommodates                                                    0.07
# price                                                           0.04
# maximum_nights                                                  0.04
# minimum_maximum_nights                                          0.05
# maximum_maximum_nights                                          0.03
# maximum_nights_avg_ntm                                          0.04
# availability_30                                                 0.10
# availability_60                                                 0.10
# availability_90                                                 0.09
# availability_365                                                0.08
# number_of_reviews                                               0.41
# number_of_reviews_ltm                                           0.24
# availability_eoy                                                0.08
# number_of_reviews_ly                                            0.23
# estimated_occupancy_l365d                                       0.25
# estimated_revenue_l365d                                         0.24
# review_scores_rating                                            0.99
# review_scores_accuracy                                          1.00
# review_scores_cleanliness                                       0.99
# review_scores_checkin                                           0.99
# review_scores_communication                                     0.99
# review_scores_location                                          0.99
# review_scores_value                                             0.99
# calculated_host_listings_count                                  0.01
# calculated_host_listings_count_entire_homes                     0.05
# calculated_host_listings_count_private_rooms                    0.08
# reviews_per_month                                               0.00
#
#                                               review_scores_cleanliness  \
# host_response_rate                                                 0.03
# host_acceptance_rate                                               0.05
# host_listings_count                                                0.01
# host_total_listings_count                                          0.00
# latitude                                                           0.05
# longitude                                                          0.06
# accommodates                                                       0.08
# price                                                              0.04
# maximum_nights                                                     0.05
# minimum_maximum_nights                                             0.05
# maximum_maximum_nights                                             0.02
# maximum_nights_avg_ntm                                             0.04
# availability_30                                                    0.09
# availability_60                                                    0.08
# availability_90                                                    0.08
# availability_365                                                   0.07
# number_of_reviews                                                  0.41
# number_of_reviews_ltm                                              0.24
# availability_eoy                                                   0.07
# number_of_reviews_ly                                               0.24
# estimated_occupancy_l365d                                          0.26
# estimated_revenue_l365d                                            0.25
# review_scores_rating                                               0.99
# review_scores_accuracy                                             0.99
# review_scores_cleanliness                                          1.00
# review_scores_checkin                                              0.99
# review_scores_communication                                        0.99
# review_scores_location                                             0.98
# review_scores_value                                                0.99
# calculated_host_listings_count                                     0.02
# calculated_host_listings_count_entire_homes                        0.05
# calculated_host_listings_count_private_rooms                       0.09
# reviews_per_month                                                  0.01
#
#                                               review_scores_checkin  \
# host_response_rate                                             0.02
# host_acceptance_rate                                           0.04
# host_listings_count                                            0.01
# host_total_listings_count                                      0.00
# latitude                                                       0.05
# longitude                                                      0.06
# accommodates                                                   0.07
# price                                                          0.05
# maximum_nights                                                 0.04
# minimum_maximum_nights                                         0.05
# maximum_maximum_nights                                         0.03
# maximum_nights_avg_ntm                                         0.04
# availability_30                                                0.10
# availability_60                                                0.09
# availability_90                                                0.09
# availability_365                                               0.08
# number_of_reviews                                              0.40
# number_of_reviews_ltm                                          0.24
# availability_eoy                                               0.08
# number_of_reviews_ly                                           0.24
# estimated_occupancy_l365d                                      0.25
# estimated_revenue_l365d                                        0.24
# review_scores_rating                                           0.99
# review_scores_accuracy                                         0.99
# review_scores_cleanliness                                      0.99
# review_scores_checkin                                          1.00
# review_scores_communication                                    0.99
# review_scores_location                                         0.99
# review_scores_value                                            0.99
# calculated_host_listings_count                                 0.02
# calculated_host_listings_count_entire_homes                    0.05
# calculated_host_listings_count_private_rooms                   0.09
# reviews_per_month                                              0.01
#
#                                               review_scores_communication  \
# host_response_rate                                                   0.02
# host_acceptance_rate                                                 0.04
# host_listings_count                                                  0.01
# host_total_listings_count                                            0.01
# latitude                                                             0.05
# longitude                                                            0.06
# accommodates                                                         0.07
# price                                                                0.05
# maximum_nights                                                       0.04
# minimum_maximum_nights                                               0.06
# maximum_maximum_nights                                               0.03
# maximum_nights_avg_ntm                                               0.04
# availability_30                                                      0.10
# availability_60                                                      0.09
# availability_90                                                      0.09
# availability_365                                                     0.08
# number_of_reviews                                                    0.41
# number_of_reviews_ltm                                                0.24
# availability_eoy                                                     0.08
# number_of_reviews_ly                                                 0.23
# estimated_occupancy_l365d                                            0.25
# estimated_revenue_l365d                                              0.24
# review_scores_rating                                                 0.99
# review_scores_accuracy                                               0.99
# review_scores_cleanliness                                            0.99
# review_scores_checkin                                                0.99
# review_scores_communication                                          1.00
# review_scores_location                                               0.99
# review_scores_value                                                  0.99
# calculated_host_listings_count                                       0.01
# calculated_host_listings_count_entire_homes                          0.05
# calculated_host_listings_count_private_rooms                         0.09
# reviews_per_month                                                    0.01
#
#                                               review_scores_location  \
# host_response_rate                                              0.02
# host_acceptance_rate                                            0.04
# host_listings_count                                             0.01
# host_total_listings_count                                       0.00
# latitude                                                        0.04
# longitude                                                       0.03
# accommodates                                                    0.07
# price                                                           0.04
# maximum_nights                                                  0.04
# minimum_maximum_nights                                          0.05
# maximum_maximum_nights                                          0.03
# maximum_nights_avg_ntm                                          0.04
# availability_30                                                 0.10
# availability_60                                                 0.09
# availability_90                                                 0.09
# availability_365                                                0.08
# number_of_reviews                                               0.40
# number_of_reviews_ltm                                           0.24
# availability_eoy                                                0.08
# number_of_reviews_ly                                            0.24
# estimated_occupancy_l365d                                       0.25
# estimated_revenue_l365d                                         0.24
# review_scores_rating                                            0.99
# review_scores_accuracy                                          0.99
# review_scores_cleanliness                                       0.98
# review_scores_checkin                                           0.99
# review_scores_communication                                     0.99
# review_scores_location                                          1.00
# review_scores_value                                             0.99
# calculated_host_listings_count                                  0.01
# calculated_host_listings_count_entire_homes                     0.05
# calculated_host_listings_count_private_rooms                    0.08
# reviews_per_month                                               0.01
#
#                                               review_scores_value  \
# host_response_rate                                           0.01
# host_acceptance_rate                                         0.04
# host_listings_count                                          0.00
# host_total_listings_count                                    0.01
# latitude                                                     0.05
# longitude                                                    0.06
# accommodates                                                 0.07
# price                                                        0.05
# maximum_nights                                               0.04
# minimum_maximum_nights                                       0.06
# maximum_maximum_nights                                       0.03
# maximum_nights_avg_ntm                                       0.04
# availability_30                                              0.10
# availability_60                                              0.10
# availability_90                                              0.10
# availability_365                                             0.09
# number_of_reviews                                            0.41
# number_of_reviews_ltm                                        0.23
# availability_eoy                                             0.09
# number_of_reviews_ly                                         0.23
# estimated_occupancy_l365d                                    0.24
# estimated_revenue_l365d                                      0.24
# review_scores_rating                                         0.99
# review_scores_accuracy                                       0.99
# review_scores_cleanliness                                    0.99
# review_scores_checkin                                        0.99
# review_scores_communication                                  0.99
# review_scores_location                                       0.99
# review_scores_value                                          1.00
# calculated_host_listings_count                               0.00
# calculated_host_listings_count_entire_homes                  0.04
# calculated_host_listings_count_private_rooms                 0.09
# reviews_per_month                                            0.00
#
#                                               calculated_host_listings_count  \
# host_response_rate                                                      0.25
# host_acceptance_rate                                                    0.01
# host_listings_count                                                     0.79
# host_total_listings_count                                               0.60
# latitude                                                                0.02
# longitude                                                               0.00
# accommodates                                                            0.00
# price                                                                   0.12
# maximum_nights                                                          0.13
# minimum_maximum_nights                                                  0.11
# maximum_maximum_nights                                                  0.09
# maximum_nights_avg_ntm                                                  0.10
# availability_30                                                         0.12
# availability_60                                                         0.15
# availability_90                                                         0.16
# availability_365                                                        0.19
# number_of_reviews                                                       0.02
# number_of_reviews_ltm                                                   0.09
# availability_eoy                                                        0.19
# number_of_reviews_ly                                                    0.09
# estimated_occupancy_l365d                                               0.09
# estimated_revenue_l365d                                                 0.07
# review_scores_rating                                                    0.01
# review_scores_accuracy                                                  0.01
# review_scores_cleanliness                                               0.02
# review_scores_checkin                                                   0.02
# review_scores_communication                                             0.01
# review_scores_location                                                  0.01
# review_scores_value                                                     0.00
# calculated_host_listings_count                                          1.00
# calculated_host_listings_count_entire_homes                             0.06
# calculated_host_listings_count_private_rooms                            0.11
# reviews_per_month                                                       0.05
#
#                                               calculated_host_listings_count_entire_homes  \
# host_response_rate                                                                   0.19
# host_acceptance_rate                                                                 0.02
# host_listings_count                                                                  0.07
# host_total_listings_count                                                            0.09
# latitude                                                                             0.02
# longitude                                                                            0.03
# accommodates                                                                         0.31
# price                                                                                0.24
# maximum_nights                                                                       0.00
# minimum_maximum_nights                                                               0.03
# maximum_maximum_nights                                                               0.00
# maximum_nights_avg_ntm                                                               0.01
# availability_30                                                                      0.04
# availability_60                                                                      0.02
# availability_90                                                                      0.00
# availability_365                                                                     0.07
# number_of_reviews                                                                    0.04
# number_of_reviews_ltm                                                                0.09
# availability_eoy                                                                     0.04
# number_of_reviews_ly                                                                 0.08
# estimated_occupancy_l365d                                                            0.08
# estimated_revenue_l365d                                                              0.04
# review_scores_rating                                                                 0.05
# review_scores_accuracy                                                               0.05
# review_scores_cleanliness                                                            0.05
# review_scores_checkin                                                                0.05
# review_scores_communication                                                          0.05
# review_scores_location                                                               0.05
# review_scores_value                                                                  0.04
# calculated_host_listings_count                                                       0.06
# calculated_host_listings_count_entire_homes                                          1.00
# calculated_host_listings_count_private_rooms                                         0.33
# reviews_per_month                                                                    0.02
#
#                                               calculated_host_listings_count_private_rooms  \
# host_response_rate                                                                    0.02
# host_acceptance_rate                                                                  0.05
# host_listings_count                                                                   0.09
# host_total_listings_count                                                             0.07
# latitude                                                                              0.03
# longitude                                                                             0.13
# accommodates                                                                          0.22
# price                                                                                 0.30
# maximum_nights                                                                        0.08
# minimum_maximum_nights                                                                0.04
# maximum_maximum_nights                                                                0.05
# maximum_nights_avg_ntm                                                                0.04
# availability_30                                                                       0.09
# availability_60                                                                       0.08
# availability_90                                                                       0.07
# availability_365                                                                      0.00
# number_of_reviews                                                                     0.08
# number_of_reviews_ltm                                                                 0.00
# availability_eoy                                                                      0.03
# number_of_reviews_ly                                                                  0.00
# estimated_occupancy_l365d                                                             0.01
# estimated_revenue_l365d                                                               0.05
# review_scores_rating                                                                  0.09
# review_scores_accuracy                                                                0.08
# review_scores_cleanliness                                                             0.09
# review_scores_checkin                                                                 0.09
# review_scores_communication                                                           0.09
# review_scores_location                                                                0.08
# review_scores_value                                                                   0.09
# calculated_host_listings_count                                                        0.11
# calculated_host_listings_count_entire_homes                                           0.33
# calculated_host_listings_count_private_rooms                                          1.00
# reviews_per_month                                                                     0.07
#
#                                               reviews_per_month
# host_response_rate                                         0.18
# host_acceptance_rate                                       0.08
# host_listings_count                                        0.06
# host_total_listings_count                                  0.06
# latitude                                                   0.04
# longitude                                                  0.07
# accommodates                                               0.00
# price                                                      0.14
# maximum_nights                                             0.13
# minimum_maximum_nights                                     0.07
# maximum_maximum_nights                                     0.07
# maximum_nights_avg_ntm                                     0.07
# availability_30                                            0.12
# availability_60                                            0.14
# availability_90                                            0.16
# availability_365                                           0.16
# number_of_reviews                                          0.32
# number_of_reviews_ltm                                      0.12
# availability_eoy                                           0.17
# number_of_reviews_ly                                       0.05
# estimated_occupancy_l365d                                  0.16
# estimated_revenue_l365d                                    0.16
# review_scores_rating                                       0.00
# review_scores_accuracy                                     0.00
# review_scores_cleanliness                                  0.01
# review_scores_checkin                                      0.01
# review_scores_communication                                0.01
# review_scores_location                                     0.01
# review_scores_value                                        0.00
# calculated_host_listings_count                             0.05
# calculated_host_listings_count_entire_homes                0.02
# calculated_host_listings_count_private_rooms               0.07
# reviews_per_month                                          1.00
#
# [33 rows x 33 columns]

# %%
privateroom_df[["availability_365", "number_of_reviews"]].corr()
# Out:
#                    availability_365  number_of_reviews
# availability_365           1.000000           0.049171
# number_of_reviews          0.049171           1.000000

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt

d = privateroom_df.copy()
rt = 'room_type' if 'room_type' in d.columns else 'room type'
for c in ['host_acceptance_rate','host_response_rate']:
    d[c] = pd.to_numeric(d[c].astype(str).str.replace('%',''), errors='coerce')

private_ = d.loc[d[rt].astype(str).str.lower().eq('private room'),
                 ['host_acceptance_rate','host_response_rate']].dropna()

sns.regplot(x='host_acceptance_rate', y='host_response_rate', data=private_,
            scatter_kws={'s':18, 'alpha':.5}, line_kws={'linewidth':2}, ci=None)
plt.title('Private room: acceptance vs response')
plt.xlabel('host_acceptance_rate'); plt.ylabel('host_response_rate')
plt.tight_layout(); plt.show()
